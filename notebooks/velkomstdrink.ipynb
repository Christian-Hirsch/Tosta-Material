# %% [markdown]
# # Aperitif

# %% [markdown]
# ## Image Classification & Object Detection

# %%
from IPython.display import HTML

# %% [markdown]
# ### Imagenet

# %% [markdown]
# <img src="images/imageNet.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# <img src="images/resnet.jpg" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ### YOLO

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("VOC3huqHrss")

# %% [markdown]
# [Joseph Redmon, Santosh Divvala, Ross Girshick, Ali Farhadi. *You Only Look Once: Unified, Real-Time Object Detection*, 2016](https://www.youtube.com/watch?v=VOC3huqHrss)

# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# ### Atari Games

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("V1eYniJ0Rnk")

# %% [markdown]
# [Google DeepMind's Deep Q-learning playing Atari Breakout](https://www.youtube.com/watch?v=V1eYniJ0Rnk)

# %% [markdown]
# ### AlphaGo

# %% [markdown]
# <img src="images/alphago.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# ## Natural Language Processing

# %% [markdown]
# ### Neural Machine Translation

# %% [markdown]
# ##BLEU of traditional systems: 20
#
# https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html

# %% [markdown]
# <img src="images/nmt.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# ### Speech Recognition & Generation

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("bd1mEm2Fy08")

# %% [markdown]
# ## Generative Models

# %% [markdown]
# ### Deepfake
# https://hackernoon.com/exploring-deepfakes-20c9947c22d9

# %% [markdown]
# <img src="images/deepfake.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# <img src="images/deepFake.gif" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# ## Pix2Pix

# %% [markdown]
# https://laughingsquid.com/edges2cats/
#
# http://knowyourmeme.com/photos/1225207-edges2cats

# %% [markdown]
# <img src="images/e2c1.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# <img src="images/e2c.jpg" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# # Why Now?

# %% [markdown]
# ## Big Data

# %% [markdown]
# <img src="images/dataGrowth.png" alt="Drawing" style="width: 1000px;"/>
# http://www.datamashup.info/the-network-impact-of-big-data/

# %% [markdown]
# ## Advances in AI

# %% [markdown]
# <img src="images/vgg16.png" alt="Drawing" style="width: 1000px;"/>
# https://blog.heuritech.com/2016/03/02/yann-lecun-lectures-at-the-college-de-france-n3/

# %% [markdown]
# ## GPU & TPU Compute Power

# %% [markdown]
# <img src="images/nvidia.jpg" alt="Drawing" style="width: 1000px;"/>
# Larry Brown, Deep Learning with GPUs

# %% [markdown]
# # Machine Learning Taxonomy

# %% [markdown]
# **Yann LeCun**

# %% [markdown]
# >Most of human and animal learning is unsupervised learning. If intelligence was a cake, __unsupervised learning__ would be the cake, __supervised learning__ would be the icing on the cake, and __reinforcement learning__ would be the cherry on the cake.

# %% [markdown]
# <img src="images/cake.jpg" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ## Unsupervised Learning

# %% [markdown]
# * AI learns __arbitrary structures in data__
# * __Examples__ image generation, anonymization
# * __Algorithms__ Clustering, Auto-Encoders, Generative Adversarial Networks

# %% [markdown]
# <img src="images/styleTrans.png" alt="Drawing" style="width: 1000px;"/>
# https://research.googleblog.com/2016/10/supercharging-style-transfer.html

# %% [markdown]
# ## Supervised Learning

# %% [markdown]
# * Machine learns via __manually annotated data__
# * __Examples__ Image recognition, online ads, recommender systems
# *  __Algorithms__ tree methods, deep learning, logistic regression, SVM

# %% [markdown]
# <img src="images/ilsvrc.png" alt="Drawing" style="width: 1000px;"/>
# http://www.image-net.org/challenges/LSVRC/2014

# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# * Agent interacts with environment -- learning by sparse _reward signals_ ar
# * __Examples__ AlphaGo, Atari, robotics
# * __Algorithms__ Q-learning, policy-based methods, actor-critic approaches

# %% [markdown]
# <img src="images/industrial.jpg" alt="Drawing" style="width: 1000px;"/>
# Wikimedia Commons User:ISAPUT / CC-BY-SA-4.0

# %% [markdown]
# ## How did we get here?

# %% [markdown]
# <img src="images/mafia.jpg" alt="Drawing" style="width: 500px;"/>
# https://www.kdnuggets.com/2015/03/talking-machine-deep-learning-gurus-p1.html

# %% [markdown]
# * **1957.** Frank Rosenblatt builds the Perceptron
# * **1986.** David E. Rumelhart, Geoffrey E. Hinton & Ronald J. Williams:  *Learning representations by back-propagating errors*
# * **1989.** Yann LeCun et al.: *Backpropagation Applied to Handwritten Zip Code Recognition*
# * **1997.** Schmidhuber & Hochreiter: *Long Short Term Memory*
# * **1998.** LeCun, Bottou, Bengio, Haffner. *Gradient-based learning applied to  document recognition*
# * **2006.** Hinton, Osindero & Teh: *A fast learning algorithm for deep belief nets*
# * **2016.** AlphaGo wins against Lee Sedol

# %% [markdown]
# ## Not covered are...

# %% [markdown]
# Attention mechanism & transformer networks

# %% [markdown]
# <img src="images/transformer.gif" alt="Drawing" style="width: 500px;"/>
# https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html

# %% [markdown]
# Adversarial examples

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("piYnd_wYlT8")

# %% [markdown]
# Interpretability & visualization

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("AgkfIQ4IGaM")

# %% [markdown]
# * Reinforcement learning
# * Speech recognition & generation
# * Object detection & semantic segmentation

# %% [markdown]
# ## Play Yourself

# %% [markdown]
# Visit http://playground.tensorflow.org and [play](./images/play.html)!
